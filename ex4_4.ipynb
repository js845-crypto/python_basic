# %%
a = 10
b = a

print(a, b) # 10 10
print(a is b)  # True 같은 객체 참조
# 10 객체 메모리를 a와 b 둘다 동일하게 참조함, 공유 객체 참조. ( 두 가지 변수가 하나의 동일한 객체 메모리를 참조)
print(a==b)
# Out:
# 10 10
# True
# True

# %%
a=10
b=10
print(a is b)
print(a == b)
#a=10, b=10이면 원래는 공유참조 아니나 메모리 낭비 때문에 공유참조로 처리함, 불변 객체에 한해서. list면 가변 객체라서 공유참조 안함
# Out:
# True
# True
