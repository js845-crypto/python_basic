# %%
t= (2,4)
print(t)
print(type(t))
# Out:
# (2, 4)
# <class 'tuple'>

# %%
t = 1, 3, 5 # 팩킹 실행: 자동으로 튜플로(1,3,5) 묶어짐, list로 안됨
print(t) 
print(type(t))
l=list(t)
print(l,type(l))


x, y, z = t # 언팩킹 실행 : 튜플이 자동으로 하나씩 풀림
print(x, y, z)
a, b = [3, 6] #(3,6) 튜플로 변경 후 언팩킹 발생
print(a,b)
# Out:
# (1, 3, 5)
# <class 'tuple'>
# [1, 3, 5] <class 'list'>
# 1 3 5
# 3 6
